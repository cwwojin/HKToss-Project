# %%
import pandas as pd

df = pd.read_csv('/Users/khb43/Desktop/HANKYUNG_WITH_TOSS_BANK-2(소민호 강사님)/week9~11 실무 프로젝트 관련/data/선정 데이터(프로젝트 데이터)/clients/demo_set.csv')

# %%
df.shape
# Out:
# (25, 115)

# %%
df
# Out:
#     SK_ID_CURR name  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0       342407  강민호       0         Cash loans           M            Y
# 1       247197  김현빈       1         Cash loans           F            Y
# 2       388971  김희교       0    Revolving loans           M            N
# 3       342954  박동현       1         Cash loans           F            N
# 4       293026  박선애       0         Cash loans           F            Y
# 5       219676  성원석       0         Cash loans           F            Y
# 6       390619  신동훈       1         Cash loans           M            Y
# 7       307654  신지민       0    Revolving loans           F            Y
# 8       294801  오손빈       1         Cash loans           F            Y
# 9       381931  위혜인       0    Revolving loans           F            N
# 10      287357  이나은       0         Cash loans           F            N
# 11      200733  이동현       1         Cash loans           F            N
# ...

# %%
df["OVERDUE_RATIO"]
# Out:
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.066667
# 4     0.000000
# 5     0.000000
# 6     0.000000
# 7     0.000000
# 8     0.142857
# 9     0.090909
# 10    0.000000
# 11    0.000000
# 12    0.000000
# 13    0.000000
# 14    0.000000
# 15    0.000000
# 16    0.000000
# 17    0.000000
# 18    0.000000
# 19    0.000000
# 20    0.000000
# 21    0.000000
# 22    0.000000
# 23    0.000000
# 24    0.000000
# Name: OVERDUE_RATIO, dtype: float64
